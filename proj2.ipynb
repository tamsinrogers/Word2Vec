# %% [markdown]
# <h1> Project 2:  Python2Vec

# %%
import os
import json
import os
from nltk import sent_tokenize
from gensim.utils import simple_preprocess
import gensim

# %% [markdown]
# <h3>TASK 1: Download a few Python repositories</h3>
#
# <p>Downloaded repositories are located in the 'repos' folder in this project's directory.</p>

# %% [markdown]
# <h3>TASK 2: Using Python, write a small program to crawl through the repositories looking for Python files, such files will have an extension of “.py”.</h3>

# %%
python_files = "python_files.txt"
fols = []
allPythonFiles = []
folders = os.listdir('repos')

for folder in folders:
    if folder[-5:] == "-main":
        fols.append(folder)
        
for i in range(len(fols)):
    
    theFolder = fols[i]

    files = os.listdir("repos/"+theFolder)
    files = [f for f in files if os.path.isfile("repos/"+theFolder+'/'+f)] #Filtering only the files

    for filename in files:
        if filename[-3:] == ".py":
            allPythonFiles.append(filename)

# %% [markdown]
# <h3>TASK 3: Aggregate the Python files found into a single text file.</h3>

# %%
with open("alltext.txt", "w+") as outfile:    
    
    for file in allPythonFiles:
        
        for folder in folders:
            
            p = "repos/" + folder + "/" + file
            
            if (os.path.isfile(p)): 
        
                with open (p, "r") as infile:
                    lines = infile.readlines()
                    outfile.writelines(lines)

# %% [markdown]
# <h3>TASK 4: Count the number of lines of code in this file, and the number of tokens (words).</h3>

# %%
file = "alltext.txt"

file1 = open('alltext.txt', 'r')
Lines = file1.readlines()

tokens = []

f = open(file)
corpus = f.read()
raw_sent = sent_tokenize(corpus)
for sent in raw_sent:
    tokens.append(simple_preprocess(sent))


print("lines: " + str(len(Lines)))
print("tokens: " + str(len(tokens[0])))
# Out:
# lines: 7302
# tokens: 59

# %% [markdown]
# <h3>TASK 5: Tokenize the lines by lowercasing everything and splitting on all whitespace and punctuation characters.</h3>

# %%
print(tokens)
# Out:
# [['import', 'configparser', 'import', 'functools', 'import', 'hashlib', 'from', 'io', 'import', 'bytesio', 'import', 'logging', 'import', 'os', 'from', 'pathlib', 'import', 'path', 'import', 'platform', 'import', 'shlex', 'import', 'shutil', 'import', 'subprocess', 'import', 'sys', 'import', 'sysconfig', 'import', 'tarfile', 'from', 'tempfile', 'import', 'import', 'textwrap', 'import', 'urllib', 'request', 'from', 'pybind', 'setup_helpers', 'import', 'pybind', 'extension', 'from', 'setuptools', 'import', 'distribution', 'extension', 'logging', 'getlogger', 'def', 'return', 'the', 'xdg', 'cache', 'directory'], ['https', 'specifications', 'freedesktop', 'org', 'basedir', 'spec', 'latest', 'cache_dir', 'os', 'environ', 'get', 'xdg_cache_home', 'if', 'not', 'cache_dir', 'cache_dir', 'os', 'path', 'expanduser', 'cache', 'if', 'cache_dir', 'startswith', 'expansion', 'failed'], ['return', 'none', 'return', 'path', 'cache_dir', 'matplotlib', 'def', 'data', 'compute', 'the', 'sha', 'hash', 'of', 'data'], ['hasher', 'hashlib', 'sha', 'hasher', 'update', 'data', 'return', 'hasher', 'hexdigest', 'functools', 'cache', 'def', 'import', 'certifi', 'import', 'ssl', 'return', 'ssl', 'cafile', 'certifi', 'where', 'def', 'url', 'sha', 'get', 'bytes', 'from', 'the', 'given', 'url', 'or', 'local', 'cache'], ['parameters', 'url', 'str', 'the', 'url', 'to', 'download'], ['sha', 'str', 'the', 'sha', 'of', 'the', 'file'], ['returns', 'bytesio', 'the', 'file', 'loaded', 'into', 'memory'], ['cache_dir', 'if', 'cache_dir', 'is', 'not', 'none', 'try', 'to', 'read', 'from', 'cache'], ['try', 'data', 'cache_dir', 'sha', 'read_bytes', 'except', 'oserror', 'pass', 'else', 'if', 'data', 'sha', 'return', 'bytesio', 'data', 'jqueryui', 'website', 'blocks', 'direct', 'downloads', 'from', 'urllib', 'request', 'default', 'user', 'agent', 'but', 'not', 'for', 'example', 'wget', 'so', 'don', 'feel', 'too', 'bad', 'passing', 'in', 'an', 'empty', 'user', 'agent'], ['with', 'urllib', 'request', 'urlopen', 'urllib', 'request', 'request', 'url', 'headers', 'user', 'agent', 'context', 'as', 'req', 'data', 'req', 'read', 'file_sha', 'data', 'if', 'file_sha', 'sha', 'raise', 'exception', 'the', 'downloaded', 'file', 'does', 'not', 'match', 'the', 'expected', 'sha'], ['url', 'was', 'expected', 'to', 'have', 'sha', 'but', 'it', 'had', 'file_sha', 'if', 'cache_dir', 'is', 'not', 'none', 'try', 'to', 'cache', 'the', 'downloaded', 'file'], ['try', 'cache_dir', 'mkdir', 'parents', 'true', 'exist_ok', 'true', 'with', 'open', 'cache_dir', 'sha', 'xb', 'as', 'fout', 'fout', 'write', 'data', 'except', 'oserror', 'pass', 'return', 'bytesio', 'data', 'def', 'urls', 'sha', 'dirname', 'obtain', 'tarball', 'from', 'cache', 'or', 'download', 'and', 'extract', 'it'], ['parameters', 'urls', 'list', 'str', 'urls', 'from', 'which', 'download', 'is', 'attempted', 'in', 'order', 'of', 'attempt', 'if', 'the', 'tarball', 'is', 'not', 'in', 'the', 'cache', 'yet'], ['sha', 'str', 'sha', 'hash', 'of', 'the', 'tarball', 'used', 'both', 'as', 'cache', 'key', 'by', 'and', 'to', 'validate', 'downloaded', 'tarball'], ['dirname', 'path', 'like', 'directory', 'where', 'the', 'tarball', 'is', 'extracted'], ['toplevel', 'path', 'build', 'dirname', 'if', 'not', 'toplevel', 'exists', 'download', 'it', 'or', 'load', 'it', 'from', 'cache'], ['try', 'import', 'certifi', 'noqa', 'except', 'importerror', 'as', 'raise', 'importerror', 'certifi', 'is', 'unavailable', 'so', 'unable', 'to', 'download', 'any', 'of', 'the', 'following', 'urls'], ['from', 'none', 'path', 'build', 'mkdir', 'exist_ok', 'true', 'for', 'url', 'in', 'urls', 'try', 'tar_contents', 'url', 'sha', 'break', 'except', 'exception', 'pass', 'else', 'raise', 'oserror', 'failed', 'to', 'download', 'any', 'of', 'the', 'following', 'urls'], ['please', 'download', 'one', 'of', 'these', 'urls', 'and', 'extract', 'it', 'into', 'build', 'at', 'the', 'top', 'level', 'of', 'the', 'source', 'repository'], ['print', 'extracting', 'urllib', 'parse', 'urlparse', 'url ...

# %% [markdown]
# <h3>TASK 6: Train your Gensim Word2Vec model with the tokenized lines of code.</h3>

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

model.build_vocab(tokens)

model.train(tokens, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (94110, 119360)

# %% [markdown]
# <h3>TASK 7: Explore the trained model by examining the closest_words to some Python keywords like “for” and “if.”  </h3> Also explore the similarity of some popular identifier names like “math” and “numpy” in your notebook.

# %%
model.wv.most_similar('for')
# Out:
# [('with', 0.9998308420181274),
#  ('and', 0.9998308420181274),
#  ('files', 0.9997860789299011),
#  ('return', 0.9997527003288269),
#  ('is', 0.9997467994689941),
#  ('check', 0.9997426271438599),
#  ('the', 0.9997404217720032),
#  ('to', 0.999734103679657),
#  ('try', 0.9997105598449707),
#  ('as', 0.9997058510780334)]

# %%
model.wv.most_similar('if')
# Out:
# [('not', 0.9995782971382141),
#  ('in', 0.9995724558830261),
#  ('run', 0.9995318055152893),
#  ('or', 0.9994338750839233),
#  ('environ', 0.9993986487388611),
#  ('sys', 0.9993723630905151),
#  ('def', 0.9993596076965332),
#  ('open', 0.9993440508842468),
#  ('cwd', 0.9992483854293823),
#  ('command', 0.9992460608482361)]

# %%
model.wv.similarity('setup','sys')
# Out:
# 0.9990017

# %%
model.wv.similarity('from','import')
# Out:
# 0.99498516

# %%
model.wv.similarity('scikit','scipy')
# Out:
# 0.999072

# %%
model.wv.similarity('first','last')
# Out:
# 0.9561706

# %%
model.wv.similarity('get','set')
# Out:
# 0.99902046

# %%
model.wv.similarity('raise','exception')
# Out:
# 0.9987032

# %%
model.wv.similarity('get','extract')
# Out:
# 0.9421532
